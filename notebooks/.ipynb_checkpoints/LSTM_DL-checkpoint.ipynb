# %% [markdown]
# #### Considering LSTM Model for diabetes prediction

# %%
import pandas as pd

# Load the dataset
data_path = '../data/processed/cleaned_diabetes_one_hot_encoding.csv'
df = pd.read_csv(data_path)

# Display the first few rows of the dataframe
print(df.head())
# Out:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level  \
# 0  80.0             0              1  25.19          6.6                  140
# 1  54.0             0              0  27.32          6.6                   80
# 2  28.0             0              0  27.32          5.7                  158
# 3  36.0             0              0  23.45          5.0                  155
# 4  76.0             1              1  20.14          4.8                  155
#
#    diabetes  gender_Female  gender_Male  gender_Other  \
# 0         0              1            0             0
# 1         0              1            0             0
# 2         0              0            1             0
# 3         0              1            0             0
# 4         0              0            1             0
#
#    smoking_history_No Info  smoking_history_current  smoking_history_former  \
# 0                        0                        0                       0
# 1                        1                        0                       0
# 2                        0                        0                       0
# 3                        0                        1                       0
# 4                        0                        1                       0
#
#    smoking_history_never  smoking_history_not current
# 0                      1                            0
# 1                      0                            0
# 2                      1                            0
# 3                      0                            0
# 4                      0                            0

# %%
# Normalizing the data
from sklearn.preprocessing import MinMaxScaler

features = df.drop('diabetes', axis=1).columns.tolist()
scaler = MinMaxScaler()

df[features] = scaler.fit_transform(df[features])

# %%
# Reshape data for LTSM
X = df.drop('diabetes', axis=1).values
Y = df['diabetes'].values

# Reshape X to be [samples, timesteps, features]
X = X.reshape((X.shape[0], 1, X.shape[1]))

# %%
# Splitting the dataset
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Build the LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# 2024-03-14 17:54:46.326324: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /N/soft/sles15/python/gnu/3.10.5/lib:/opt/cray/pe/gcc/11.2.0/snos/lib64:/opt/cray/pe/papi/6.0.0.17/lib64:/opt/cray/libfabric/1.11.0.4.111/lib64
# 2024-03-14 17:54:46.326398: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-03-14 17:55:22.023282: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-03-14 17:55:22.023366: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (x1000c3s0b0n1): /proc/driver/nvidia/version does not exist
# 2024-03-14 17:55:22.024681: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import classification_report, roc_auc_score

# Add precision and recall to the model's metrics
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', Precision(), Recall()])

# Train the model (ensure you have trained your model with these metrics before evaluating)
history = model.fit(
    X_train, Y_train, 
    epochs=100, 
    batch_size=64, 
    validation_split=0.2, 
    verbose=2
)

# Evaluate the model on the test set with additional metrics
loss, accuracy, precision, recall = model.evaluate(X_test, Y_test, verbose=2)
print(f'Test Accuracy: {accuracy*100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')

# For F1-score and ROC-AUC, use sklearn's utilities as they're not directly supported as Keras metrics during training
from sklearn.metrics import f1_score, roc_auc_score

# Predict probabilities for ROC AUC
y_probs = model.predict(X_test)[:, 0]  # assuming your model outputs probabilities for class 1

# Predict class labels for F1 score and other metrics
y_pred = (y_probs > 0.5).astype('int32')

# Calculate F1 score
f1 = f1_score(Y_test, y_pred)
print(f'F1 Score: {f1:.2f}')

# Calculate ROC AUC Score
roc_auc = roc_auc_score(Y_test, y_probs)
print(f'ROC AUC Score: {roc_auc:.2f}')
# Out:
# Epoch 1/100
# 893/893 - 5s - loss: 0.0898 - accuracy: 0.9707 - precision: 0.9452 - recall: 0.6430 - val_loss: 0.0890 - val_accuracy: 0.9725 - val_precision: 0.9444 - val_recall: 0.6651 - 5s/epoch - 6ms/step
# Epoch 2/100
# 893/893 - 3s - loss: 0.0898 - accuracy: 0.9711 - precision: 0.9487 - recall: 0.6451 - val_loss: 0.0895 - val_accuracy: 0.9714 - val_precision: 0.9558 - val_recall: 0.6393 - 3s/epoch - 3ms/step
# Epoch 3/100
# 893/893 - 3s - loss: 0.0897 - accuracy: 0.9705 - precision: 0.9450 - recall: 0.6407 - val_loss: 0.0890 - val_accuracy: 0.9723 - val_precision: 0.9528 - val_recall: 0.6546 - 3s/epoch - 3ms/step
# Epoch 4/100
# 893/893 - 3s - loss: 0.0898 - accuracy: 0.9705 - precision: 0.9443 - recall: 0.6399 - val_loss: 0.0891 - val_accuracy: 0.9725 - val_precision: 0.9556 - val_recall: 0.6565 - 3s/epoch - 3ms/step
# Epoch 5/100
# 893/893 - 3s - loss: 0.0895 - accuracy: 0.9706 - precision: 0.9464 - recall: 0.6407 - val_loss: 0.0888 - val_accuracy: 0.9721 - val_precision: 0.9590 - val_recall: 0.6469 - 3s/epoch - 3ms/step
# Epoch 6/100
# 893/893 - 3s - loss: 0.0897 - accuracy: 0.9711 - precision: 0.9497 - recall: 0.6456 - val_loss: 0.0894 - val_accuracy: 0.9723 - val_precision: 0.9808 - val_recall: 0.6345 - 3s/epoch - 3ms/step
# Epoch 7/100
# 893/893 - 3s - loss: 0.0896 - accuracy: 0.9707 - precision: 0.9480 - recall: 0.6404 - val_loss: 0.0887 - val_accuracy: 0.9718 - val_precision: 0.9485 - val_recall: 0.6508 - 3s/epoch - 3ms/step
# Epoch 8/100
# 893/893 - 3s - loss: 0.0896 - accuracy: 0.9704 - precision: 0.9412 - recall: 0.6414 - val_loss: 0.0890 - val_accuracy: 0.9719 - val_precision: 0.9736 - val_recall: 0.6345 - 3s/epoch - 3ms/step
# Epoch 9/100
# 893/893 - 3s - loss: 0.0898 - accuracy: 0.9707 - precision: 0.9449 - recall: 0.6428 - val_loss: 0.0886 - val_accuracy: 0.9727 - val_precision: 0.9595 - val_recall: 0.6555 - 3s/epoch - 3ms/step
# Epoch 10/100
# 893/893 - 3s - loss: 0.0894 - accuracy: 0.9708 - precision: 0.9488 - recall: 0.6418 - val_loss: 0.0888 - val_accuracy: 0.9722 - val_precision: 0.9711 - val_recall: 0.6403 - 3s/epoch - 3ms/step
# Epoch 11/100
# 893/893 - 3s - loss: 0.0892 - accuracy: 0.9709 - precision: 0.9489 - recall: 0.6432 - val_loss: 0.0891 - val_accuracy: 0.9721 - val_precision: 0.9779 - val_recall: 0.6345 - 3s/epoch - 3ms/step
# Epoch 12/100
# 893/893 - 3s - loss: 0.0892 - accuracy: 0.9709 - precision: 0.9491 - recall: 0.6421 - val_loss: 0.0886 - val_accuracy: 0.9725 - val_precision: 0.9468 - val_recall: 0.6622 - 3s/epoch - 3ms/step
# Epoch 13/100
# 893/893 - 3s - loss: 0.0892 - accuracy: 0.9711 - precision: 0.9496 - recall: 0.6447 - val_loss: 0.0887 - val_accuracy: 0.9723 - val_precision: 0.9503 - val_recall: 0.6565 - 3s/epoch - 3ms/step
# Epoch 14/100
# 893/893 - 3s - loss: 0.0892 - accuracy: 0.9708 - precision: 0.9475 - recall: 0.6430 - val_loss: 0.0887 - val_accuracy: 0.9718 - val_precision: 0.9549 - val_recall: 0.6469 - 3s/epoch - 3ms/step
# Epoch 15/100
# 893/893 - 3s - loss: 0.0891 - accuracy: 0.9706 - precision: 0.9445 - recall: 0.6418 - val_loss: 0.0889 - val_accuracy: 0.9724 - val_precision: 0.9725 - val_recall: 0.6422 - 3s/epoch - 3ms/step
# Epoch 16/100
# 893/893 - 3s - loss: 0.0892 - accuracy: 0.9708 - precision: 0.9447 - recall: 0.6440 - val_loss: 0.0925 - val_accuracy: 0.9683 - val_precision: 0.8385 - val_recall: 0.7032 - 3s/epoch - 3ms/step
# Epoch 17/100
# 893/893 - 3s - loss: 0.0891 - accuracy: 0.9710 - precision: 0.9505 - recall: 0.6428 - val_loss: 0.0890 - val_accuracy: 0.9723 - val_precision: 0.9851 - val_recall: 0.6326 - 3s/epoch - 3ms/step
# Epoch 18/100
# 893/893 - 3s - loss: 0.0890 - accuracy: 0.9707 - precision: 0.9474 - recall: 0.6407 - val_loss: 0.0890 - val_accuracy: 0.9709 - val_precision: 0.9041 - val_recall: 0.6746 - 3s/epoch - 3ms/step
# Epoch 19/100
# 893/893 - 3s - loss: 0.0889 - accuracy: 0.9710 - precision: 0.9480 - recall: 0.6454 - val_loss: 0.0884 - val_accuracy: 0.9732 - val_precision: 0.9812 - val_recall: 0.6479 - 3s/epoch - 3ms/step
# Epoch 20/100
# 893/893 - 3s - loss: 0.0889 - accuracy: 0.9713 - precision: 0.9581 - recall: 0.6414 - val_loss: 0.0884 - val_accuracy: 0.9707 - val_precision: 0.9090 - val_recall: 0.6670 - 3s/epoch - 3ms/step
# Epoch 21/100
# 893/893 - 3s - loss: 0.0889 - accuracy: 0.9710 - precision: 0.9465 - recall: 0.6461 - val_loss: 0.0880 - val_accuracy: 0.9730 - val_precision: 0.9797 - val_recall: 0.6450 - 3s/epoch - 3ms/step
# Epoch 22/100
# 893/893 - 3s - loss: 0.0887 - accuracy: 0.9707 - precision: 0.9496 - recall: 0.6397 - val_loss: 0.0896 - val_accuracy: 0.9721 - val_precision: 0.9836 - val_recall: 0.6307 - 3s/epoch - 3ms/step
# Epoch 23/100
# 893/893 - 3s - loss: 0.0887 - accuracy: 0.9709 - precision: 0.9457 - recall: 0.6454 - val_loss: 0.0895 - val_accuracy: 0.9709 - val_precision: 0.9020 - val_recall: 0.6765 - 3s/epoch - 3ms/step
# Epoch 24/100
# 893/893 - 3s - loss: 0.0887 - accuracy: 0.9711 - precision: 0.9491 - recall: 0.6461 - val_loss: 0.0882 - val_accuracy: 0.9725 - val_precision: 0.9469 - val_recall: 0.6632 - 3s/epoch - 3ms/step
# Epoch 25/100
# 893/893 - 3s - loss: 0.0887 - accuracy: 0.9711 - precision: 0.9522 - recall: 0.6437 - val_loss: 0.0881 - val_accuracy: 0.9725 - val_precision: 0.9795 - val_recall: 0.6393 - 3s/epoch - 3ms/step
# Epoch 26/100
# 893/893 - 3s - loss: 0.0887 - accuracy: 0.9710 - precision: 0.9495 - recall: 0.6435 - val_loss: 0.0883 - val_accuracy: 0.9722 - val_precision: 0.9697 - val_recall: 0.6412 - 3s/epoch - 3ms/step
# Epoch 27/100
# 893/893 - 3s - loss: 0.0887 - accuracy: 0.9709 - precision: 0.9442 - recall: 0.6463 - val_loss: 0.0879 - val_accuracy: 0.9721 - val_precision: 0.9526 - val_recall: 0.6527 - 3s/epoch - 3ms/step
# Epoch 28/100
# 893/893 - 3s - loss: 0.0886 - accuracy: 0.9710 - precision: 0.9490 - recall: 0.6444 - val_loss: 0.0878 - val_accuracy: 0.9719 - val_precision: 0.9273 - val_recall: 0.6698 - 3s/epoch - 3ms/step
# Epoch 29/100
# 893/893 - 3s - loss: 0.0883 - accuracy: 0.9710 - precision: 0.9487 - recall: 0.6449 - val_loss: 0.0878 - val_accuracy: 0.9724 - val_precision: 0.9671 - val_recall: 0.6460 - 3s/epoch - 3ms/step
# Epoch 30/100
# 893/893 - 3s - loss: 0.0885 - accuracy: 0.9706 - precision: 0.9444 - recall: 0.6414 - val_loss: 0.0879 - val_accuracy: 0.9732 - val_precision: 0.9717 - val_recall: 0.6546 - 3s/epoch - 3ms/step
# Epoch 31/100
# 893/893 - 3s - loss: 0.0882 - accuracy: 0.9714 - precision: 0.9556 - recall: 0.6447 - val_loss: 0.0898 - val_accuracy: 0.9701 - val_precision: 0.8829 - val_recall: 0.6832 - 3s/epoch - 3ms/step
# Epoch 32/100
# 893/893 - 3s - loss: 0.0885 - accuracy: 0.9712 - precision: 0.9464 - recall: 0.6489 - val_loss: 0.0886 - val_accuracy: 0.9725 - val_precision: 0.9409 - val_recall: 0.6679 - 3s/epoch - 3ms/step
# Epoch 33/100
# 893/893 - 3s - loss: 0.0882 - accuracy: 0.9711 - precision: 0.9518 - recall: 0.6430 - val_loss: 0.0878 - val_accuracy: 0.9732 - val_precision: 0.9716 - val_recall: 0.6536 - 3s/epoch - 3ms/step
# Epoch 34/100
# 893/893 - 3s - loss: 0.0882 - accuracy: 0.9709 - precision: 0.9495 - recall: 0.6423 - val_loss: 0.0877 - val_accuracy: 0.9708 - val_precision: 0.9168 - val_recall: 0.6622 - 3s/epoch - 3ms/step
# Epoch 35/100
# 893/893 - 3s - loss: 0.0882 - accuracy: 0.9713 - precision: 0.9533 - recall: 0.6449 - val_loss: 0.0878 - val_accuracy: 0.9728 - val_precision: 0.9532 - val_recall: 0.6613 - 3s/epoch - 3ms/step
# Epoch 36/100
# 893/893 - 3s - loss: 0.0881 - accuracy: 0.9711 - precision: 0.9481 - recall: 0.6458 - val_loss: 0.0876 - val_accuracy: 0.9732 - val_precision: 0.9703 - val_recall: 0.6555 - 3s/epoch - 3ms/step
# Epoch 37/100
# 893/893 - 3s - loss: 0.0880 - accuracy: 0.9711 - precision: 0.9488 - recall: 0.6463 - val_loss: 0.0881 - val_accuracy: 0.9713 - val_precision: 0.9197 - val_recall: 0.6670 - 3s/epoch - 3ms/step
# Epoch 38/100
# 893/893 - 3s - loss: 0.0881 - accuracy: 0.9710 - precision: 0.9473 - recall: 0.6447 - val_loss: 0.0895 - val_accuracy: 0.9717 - val_precision: 0.9939 - val_recall: 0.6183 - 3s/epoch - 3ms/step
# Epoch 39/100
# 893/893 - 3s - loss: 0.0881 - accuracy: 0.9711 - precision: 0.9487 - recall: 0.6451 - val_loss: 0.0876 - val_accuracy: 0.9730 - val_precision: 0.9523 - val_recall: 0.6660 - 3s/epoch - 3ms/step
# Epoch 40/100
# 893/893 - 3s - loss: 0.0881 - accuracy: 0.9711 - precision: 0.9541 - recall: 0.6421 - val_loss: 0.0882 - val_accuracy: 0.9716 - val_precision: 0.9666 - val_recall: 0.6345 - 3s/epoch - 3ms/step
# Epoch 41/100
# 893/893 - 3s - loss: 0.0879 - accuracy: 0.9710 - precision: 0.9480 - recall: 0.6451 - val_loss: 0.0874 - val_accuracy: 0.9728 - val_precision: 0.9647 - val_recall: 0.6527 - 3s/epoch - 3ms/step
# Epoch 42/100
# 893/893 - 3s - loss: 0.0878 - accuracy: 0.9712 - precision: 0.9501 - recall: 0.6463 - val_loss: 0.0890 - val_accuracy: 0.9720 - val_precision: 0.9208 - val_recall: 0.6765 - 3s/epoch - 3ms/step
# Epoch 43/100
# 893/893 - 3s - loss: 0.0879 - accuracy: 0.9715 - precision: 0.9550 - recall: 0.6461 - val_loss: 0.0876 - val_accuracy: 0.9705 - val_precision: 0.9066 - val_recall: 0.6670 - 3s/epoch - 3ms/step
# Epoch 44/100
# 893/893 - 3s - loss: 0.0879 - accuracy: 0.9714 - precision: 0.9537 - recall: 0.6463 - val_loss: 0.0875 - val_accuracy: 0.9735 - val_precision: 0.9813 - val_recall: 0.6517 - 3s/epoch - 3ms/step
# Epoch 45/100
# 893/893 - 3s - loss: 0.0878 - accuracy: 0.9714 - precision: 0.9531 - recall: 0.6468 - val_loss: 0.0880 - val_accuracy: 0.9714 - val_precision: 0.9198 - val_recall: 0.6679 - 3s/epoch - 3ms/step
# Epoch 46/100
# 893/893 - 3s - loss: 0.0878 - accuracy: 0.9708 - precision: 0.9457 - recall: 0.6442 - val_loss: 0.0872 - val_accuracy: 0.9730 - val_precision: 0.9547 - val_recall: 0.6632 - 3s/epoch - 3ms/step
# Epoch 47/100
# 893/893 - 3s - loss: 0.0875 - accuracy: 0.9710 - precision: 0.9496 - recall: 0.6437 - val_loss: 0.0908 - val_accuracy: 0.9688 - val_precision: 0.8526 - val_recall: 0.6956 - 3s/epoch - 3ms/step
# Epoch 48/100
# 893/893 - 3s - loss: 0.0876 - accuracy: 0.9714 - precision: 0.9524 - recall: 0.6470 - val_loss: 0.0878 - val_accuracy: 0.9710 - val_precision: 0.9106 - val_recall: 0.6708 - 3s/epoch - 3ms/step
# Epoch 49/100
# 893/893 - 3s - loss: 0.0875 - accuracy: 0.9710 - precision: 0.9443 - recall: 0.6482 - val_loss: 0.0875 - val_accuracy: 0.9730 - val_precision: 0.9769 - val_recall: 0.6469 - 3s/epoch - 3ms/step
# Epoch 50/100
# 893/893 - 3s - loss: 0.0877 - accuracy: 0.9712 - precision: 0.9514 - recall: 0.6456 - val_loss: 0.0869 - val_accuracy: 0.9730 - val_precision: 0.9572 - val_recall: 0.6613 - 3s/epoch - 3ms/step
# Epoch 51/100
# 893/893 - 3s - loss: 0.0875 - accuracy: 0.9711 - precision: 0.9510 - recall: 0.6447 - val_loss: 0.0871 - val_accuracy: 0.9732 - val_precision: 0.9599 - val_recall: 0.6632 - 3s/epoch - 3ms/step
# Epoch 52/100
# 893/893 - 3s - loss: 0.0874 - accuracy: 0.9712 - precision: 0.9494 - recall: 0.6461 - val_loss: 0.0875 - val_accuracy: 0.9726 - val_precision: 0.9881 - val_recall: 0.6345 - 3s/epoch - 3ms/step
# Epoch 53/100
# 893/893 - 3s - loss: 0.0874 - accuracy: 0.9712 - precision: 0.9526 - recall: 0.6447 - val_loss: 0.0872 - val_accuracy: 0.9723 - val_precision: 0.9466 - val_recall: 0.6594 - 3s/epoch - 3ms/step
# Epoch 54/100
# 893/893 - 3s - loss: 0.0872 - accuracy: 0.9710 - precision: 0.9524 - recall: 0.6414 - val_loss: 0.0877 - val_accuracy: 0.9715 - val_precision: 0.9146 - val_recall: 0.6746 - 3s/epoch - 3ms/step
# Epoch 55/100
# 893/893 - 3s - loss: 0.0875 - accuracy: 0.9714 - precision: 0.9515 - recall: 0.6473 - val_loss: 0.0868 - val_accuracy: 0.9731 - val_precision: 0.9663 - val_recall: 0.6565 - 3s/epoch - 3ms/step
# Epoch 56/100
# 893/893 - 3s - loss: 0.0873 - accuracy: 0.9715 - precision: 0.9541 - recall: 0.6473 - val_loss: 0.0871 - val_accuracy: 0.9730 - val_precision: 0.9649 - val_recall: 0.6555 - 3s/epoch - 3ms/step
# Epoch 57/100
# 893/893 - 3s - loss: 0.0874 - accuracy: 0.9709 - precision: 0.9504 - recall: 0.6416 - val_loss: 0.0867 - val_accuracy: 0.9728 - val_precision: 0.9609 - val_recall: 0.6565 - 3s/epoch - 3ms/step
# Epoch 58/100
# 893/893 - 3s - loss: 0.0872 - accuracy: 0.9708 - precision: 0.9451 - recall: 0.6449 - val_loss: 0.0879 - val_accuracy: 0.9726 - val_precision: 0.9768 - val_recall: 0.6422 - 3s/epoch - 3ms/step
# Epoch 59/100
# 893/893 - 3s - loss: 0.0874 - accuracy: 0.9712 - precision: 0.9533 - recall: 0.6444 - val_loss: 0.0870 - val_accuracy: 0.9728 - val_precision: 0.9825 - val_recall: 0.6412 - 3s/epoch - 3ms/step
# Epoch 60/100
# 893/893 - 3s - loss: 0.0872 - accuracy: 0.9711 - precision: 0.9490 - recall: 0.6454 - val_loss: 0.0899 - val_accuracy: 0.9712 - val_precision: 0.8957 - val_recall: 0.6880 - 3s/epoch - 3ms/step
# Epoch 61/100
# 893/893 - 3s - loss: 0.0873 - accuracy: 0.9713 - precision: 0.9520 - recall: 0.6458 - val_loss: 0.0869 - val_accuracy: 0.9729 - val_precision: 0.9811 - val_recall: 0.6431 - 3s/epoch - 3ms/step
# Epoch 62/100
# 893/893 - 3s - loss: 0.0871 - accuracy: 0.9712 - precision: 0.9526 - recall: 0.6444 - val_loss: 0.0877 - val_accuracy: 0.9723 - val_precision: 0.9302 - val_recall: 0.6737 - 3s/epoch - 3ms/step
# Epoch 63/100
# 893/893 - 3s - loss: 0.0870 - accuracy: 0.9710 - precision: 0.9505 - recall: 0.6423 - val_loss: 0.0869 - val_accuracy: 0.9725 - val_precision: 0.9409 - val_recall: 0.6679 - 3s/epoch - 3ms/step
# Epoch 64/100
# 893/893 - 3s - loss: 0.0871 - accuracy: 0.9710 - precision: 0.9483 - recall: 0.6447 - val_loss: 0.0879 - val_accuracy: 0.9728 - val_precision: 0.9925 - val_recall: 0.6336 - 3s/epoch - 3ms/step
# Epoch 65/100
# 893/893 - 3s - loss: 0.0871 - accuracy: 0.9715 - precision: 0.9554 - recall: 0.6465 - val_loss: 0.0885 - val_accuracy: 0.9702 - val_precision: 0.8897 - val_recall: 0.6775 - 3s/epoch - 3ms/step
# Epoch 66/100
# 893/893 - 3s - loss: 0.0871 - accuracy: 0.9711 - precision: 0.9503 - recall: 0.6449 - val_loss: 0.0868 - val_accuracy: 0.9732 - val_precision: 0.9812 - val_recall: 0.6479 - 3s/epoch - 3ms/step
# Epoch 67/100
# 893/893 - 3s - loss: 0.0869 - accuracy: 0.9714 - precision: 0.9512 - recall: 0.6477 - val_loss: 0.0869 - val_accuracy: 0.9732 - val_precision: 0.9757 - val_recall: 0.6517 - 3s/epoch - 3ms/step
# Epoch 68/100
# 893/893 - 3s - loss: 0.0869 - accuracy: 0.9715 - precision: 0.9579 - recall: 0.6442 - val_loss: 0.0878 - val_accuracy: 0.9714 - val_precision: 0.9188 - val_recall: 0.6698 - 3s/epoch - 3ms/step
# Epoch 69/100
# 893/893 - 3s - loss: 0.0868 - accuracy: 0.9713 - precision: 0.9514 - recall: 0.6461 - val_loss: 0.0871 - val_accuracy: 0.9711 - val_precision: 0.9118 - val_recall: 0.6708 - 3s/epoch - 3ms/step
# Epoch 70/100
# 893/893 - 3s - loss: 0.0867 - accuracy: 0.9714 - precision: 0.9503 - recall: 0.6489 - val_loss: 0.0868 - val_accuracy: 0.9730 - val_precision: 0.9756 - val_recall: 0.6489 - 3s/epoch - 3ms/step
# Epoch 71/100
# 893/893 - 3s - loss: 0.0867 - accuracy: 0.9712 - precision: 0.9511 - recall: 0.6461 - val_loss: 0.0868 - val_accuracy: 0.9730 - val_precision: 0.9584 - val_recall: 0.6603 - 3s/epoch - 3ms/step
# Epoch 72/100
# 893/893 - 3s - loss: 0.0865 - accuracy: 0.9715 - precision: 0.9538 - recall: 0.6475 - val_loss: 0.0875 - val_accuracy: 0.9727 - val_precision: 0.9925 - val_recall: 0.6326 - 3s/epoch - 3ms/step
# Epoch 73/100
# 893/893 - 3s - loss: 0.0867 - accuracy: 0.9713 - precision: 0.9530 - recall: 0.6458 - val_loss: 0.0867 - val_accuracy: 0.9729 - val_precision: 0.9534 - val_recall: 0.6632 - 3s/epoch - 3ms/step
# Epoch 74/100
# 893/893 - 3s - loss: 0.0866 - accuracy: 0.9713 - precision: 0.9530 - recall: 0.6451 - val_loss: 0.0863 - val_accuracy: 0.9729 - val_precision: 0.9546 - val_recall: 0.6622 - 3s/epoch - 3ms/step
# Epoch 75/100
# 893/893 - 3s - loss: 0.0866 - accuracy: 0.9717 - precision: 0.9546 - recall: 0.6501 - val_loss: 0.0864 - val_accuracy: 0.9735 - val_precision: 0.9841 - val_recall: 0.6498 - 3s/epoch - 3ms/step
# Epoch 76/100
# 893/893 - 3s - loss: 0.0864 - accuracy: 0.9715 - precision: 0.9560 - recall: 0.6456 - val_loss: 0.0871 - val_accuracy: 0.9709 - val_precision: 0.9052 - val_recall: 0.6746 - 3s/epoch - 3ms/step
# Epoch 77/100
# 893/893 - 3s - loss: 0.0863 - accuracy: 0.9713 - precision: 0.9511 - recall: 0.6463 - val_loss: 0.0882 - val_accuracy: 0.9720 - val_precision: 0.9122 - val_recall: 0.6842 - 3s/epoch - 3ms/step
# Epoch 78/100
# 893/893 - 3s - loss: 0.0865 - accuracy: 0.9715 - precision: 0.9547 - recall: 0.6465 - val_loss: 0.0864 - val_accuracy: 0.9733 - val_precision: 0.9717 - val_recall: 0.6555 - 3s/epoch - 3ms/step
# Epoch 79/100
# 893/893 - 3s - loss: 0.0864 - accuracy: 0.9713 - precision: 0.9470 - recall: 0.6494 - val_loss: 0.0869 - val_accuracy: 0.9729 - val_precision: 0.9472 - val_recall: 0.6679 - 3s/epoch - 3ms/step
# Epoch 80/100
# 893/893 - 3s - loss: 0.0863 - accuracy: 0.9717 - precision: 0.9565 - recall: 0.6487 - val_loss: 0.0863 - val_accuracy: 0.9733 - val_precision: 0.9812 - val_recall: 0.6489 - 3s/epoch - 3ms/step
# Epoch 81/100
# 893/893 - 3s - loss: 0.0862 - accuracy: 0.9712 - precision: 0.9507 - recall: 0.6458 - val_loss: 0.0864 - val_accuracy: 0.9733 - val_precision: 0.9869 - val_recall: 0.6450 - 3s/epoch - 3ms/step
# Epoch 82/100
# 893/893 - 3s - loss: 0.0862 - accuracy: 0.9717 - precision: 0.9578 - recall: 0.6477 - val_loss: 0.0878 - val_accuracy: 0.9721 - val_precision: 0.9209 - val_recall: 0.6775 - 3s/epoch - 3ms/step
# Epoch 83/100
# 893/893 - 3s - loss: 0.0861 - accuracy: 0.9714 - precision: 0.9550 - recall: 0.6451 - val_loss: 0.0861 - val_accuracy: 0.9734 - val_precision: 0.9704 - val_recall: 0.6574 - 3s/epoch - 3ms/step
# Epoch 84/100
# 893/893 - 3s - loss: 0.0861 - accuracy: 0.9715 - precision: 0.9538 - recall: 0.6477 - val_loss: 0.0862 - val_accuracy: 0.9735 - val_precision: 0.9652 - val_recall: 0.6622 - 3s/epoch - 3ms/step
# Epoch 85/100
# 893/893 - 3s - loss: 0.0860 - accuracy: 0.9718 - precision: 0.9537 - recall: 0.6515 - val_loss: 0.0857 - val_accuracy: 0.9735 - val_precision: 0.9799 - val_recall: 0.6517 - 3s/epoch - 3ms/step
# Epoch 86/100
# 893/893 - 3s - loss: 0.0860 - accuracy: 0.9719 - precision: 0.9583 - recall: 0.6498 - val_loss: 0.0859 - val_accuracy: 0.9734 - val_precision: 0.9575 - val_recall: 0.6670 - 3s/epoch - 3ms/step
# Epoch 87/100
# 893/893 - 3s - loss: 0.0861 - accuracy: 0.9717 - precision: 0.9588 - recall: 0.6473 - val_loss: 0.0863 - val_accuracy: 0.9716 - val_precision: 0.9159 - val_recall: 0.6756 - 3s/epoch - 3ms/step
# Epoch 88/100
# 893/893 - 3s - loss: 0.0861 - accuracy: 0.9719 - precision: 0.9567 - recall: 0.6510 - val_loss: 0.0860 - val_accuracy: 0.9725 - val_precision: 0.9480 - val_recall: 0.6613 - 3s/epoch - 3ms/step
# Epoch 89/100
# 893/893 - 3s - loss: 0.0860 - accuracy: 0.9714 - precision: 0.9543 - recall: 0.6454 - val_loss: 0.0878 - val_accuracy: 0.9729 - val_precision: 0.9955 - val_recall: 0.6336 - 3s/epoch - 3ms/step
# Epoch 90/100
# 893/893 - 3s - loss: 0.0859 - accuracy: 0.9717 - precision: 0.9559 - recall: 0.6487 - val_loss: 0.0857 - val_accuracy: 0.9736 - val_precision: 0.9759 - val_recall: 0.6565 - 3s/epoch - 3ms/step
# Epoch 91/100
# 893/893 - 3s - loss: 0.0858 - accuracy: 0.9716 - precision: 0.9549 - recall: 0.6487 - val_loss: 0.0886 - val_accuracy: 0.9709 - val_precision: 0.8855 - val_recall: 0.6937 - 3s/epoch - 3ms/step
# Epoch 92/100
# 893/893 - 3s - loss: 0.0855 - accuracy: 0.9720 - precision: 0.9580 - recall: 0.6513 - val_loss: 0.0863 - val_accuracy: 0.9725 - val_precision: 0.9326 - val_recall: 0.6737 - 3s/epoch - 3ms/step
# Epoch 93/100
# 893/893 - 3s - loss: 0.0856 - accuracy: 0.9718 - precision: 0.9576 - recall: 0.6496 - val_loss: 0.0870 - val_accuracy: 0.9730 - val_precision: 0.9391 - val_recall: 0.6765 - 3s/epoch - 3ms/step
# Epoch 94/100
# 893/893 - 3s - loss: 0.0858 - accuracy: 0.9714 - precision: 0.9524 - recall: 0.6468 - val_loss: 0.0859 - val_accuracy: 0.9732 - val_precision: 0.9624 - val_recall: 0.6603 - 3s/epoch - 3ms/step
# Epoch 95/100
# 893/893 - 3s - loss: 0.0856 - accuracy: 0.9716 - precision: 0.9545 - recall: 0.6480 - val_loss: 0.0865 - val_accuracy: 0.9734 - val_precision: 0.9771 - val_recall: 0.6527 - 3s/epoch - 3ms/step
# Epoch 96/100
# 893/893 - 3s - loss: 0.0858 - accuracy: 0.9717 - precision: 0.9604 - recall: 0.6456 - val_loss: 0.0856 - val_accuracy: 0.9727 - val_precision: 0.9422 - val_recall: 0.6689 - 3s/epoch - 3ms/step
# Epoch 97/100
# 893/893 - 3s - loss: 0.0857 - accuracy: 0.9718 - precision: 0.9559 - recall: 0.6496 - val_loss: 0.0860 - val_accuracy: 0.9733 - val_precision: 0.9537 - val_recall: 0.6689 - 3s/epoch - 3ms/step
# Epoch 98/100
# 893/893 - 3s - loss: 0.0855 - accuracy: 0.9717 - precision: 0.9571 - recall: 0.6473 - val_loss: 0.0854 - val_accuracy: 0.9737 - val_precision: 0.9828 - val_recall: 0.6527 - 3s/epoch - 3ms/step
# Epoch 99/100
# 893/893 - 3s - loss: 0.0854 - accuracy: 0.9715 - precision: 0.9522 - recall: 0.6484 - val_loss: 0.0855 - val_accuracy: 0.9740 - val_precision: 0.9843 - val_recall: 0.6565 - 3s/epoch - 3ms/step
# Epoch 100/100
# 893/893 - 3s - loss: 0.0854 - accuracy: 0.9719 - precision: 0.9615 - recall: 0.6475 - val_loss: 0.0855 - val_accuracy: 0.9725 - val_precision: 0.9456 - val_recall: 0.6632 - 3s/epoch - 3ms/step
# 558/558 - 1s - loss: 0.0916 - accuracy: 0.9695 - precision: 0.9366 - recall: 0.6381 - 649ms/epoch - 1ms/step
# Test Accuracy: 96.95%
# Precision: 0.94
# Recall: 0.64
# 558/558 [==============================] - 1s 974us/step
# F1 Score: 0.76
# ROC AUC Score: 0.97
